# %%
from hypothesis import strategies as st, given
import pyprevent
import numpy as np
import jupyter_black

jupyter_black.load(lab=True)
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %%
sex_strategy = st.sampled_from(["male", "female"])
age_strategy = st.floats(min_value=30.0, max_value=79.0)
total_cholesterol_strategy = st.floats(min_value=130.0, max_value=320.0)
hdl_cholesterol_strategy = st.floats(min_value=20.0, max_value=100.0)
systolic_bp_strategy = st.floats(min_value=90.0, max_value=200.0)
boolean_strategy = st.booleans()
bmi_strategy = st.floats(min_value=18.5, max_value=39.9)
egfr_strategy = st.floats(min_value=15.0, max_value=140.0)


# Example of using these strategies to generate a test case
@st.composite
def generate_test_case(draw):
    return {
        "sex": draw(sex_strategy),
        "age": draw(age_strategy),
        "total_cholesterol": draw(total_cholesterol_strategy),
        "hdl_cholesterol": draw(hdl_cholesterol_strategy),
        "systolic_bp": draw(systolic_bp_strategy),
        "has_diabetes": draw(boolean_strategy),
        "current_smoker": draw(boolean_strategy),
        "bmi": draw(bmi_strategy),
        "egfr": draw(egfr_strategy),
        "on_htn_meds": draw(boolean_strategy),
        "on_cholesterol_meds": draw(boolean_strategy),
    }

# %%
@given(generate_test_case())
def test_batch_calculate_10_yr_ascvd_risk(test_case):
    result = pyprevent.calculate_10_yr_ascvd_risk(**test_case)
    test_case["10_yr_ascvd_risk"] = np.round(result, 1)
    print(test_case)
    print()

# %%
test_batch_calculate_10_yr_ascvd_risk()
# Out:
# {'sex': 'male', 'age': 30.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 20.0, 'systolic_bp': 90.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 19.0, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 3.9}
#
# {'sex': 'male', 'age': 30.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 20.0, 'systolic_bp': 90.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 3.9}
#
# {'sex': 'female', 'age': 30.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 20.0, 'systolic_bp': 90.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 5.1}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 20.000000000000004, 'systolic_bp': 91.0, 'has_diabetes': True, 'current_smoker': True, 'bmi': 18.500000000000004, 'egfr': 116.61723396924599, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 13.8}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 130.0, 'hdl_cholesterol': 20.0, 'systolic_bp': 90.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 5.1}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.0, 'hdl_cholesterol': 50.16239982913814, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 38.9, 'egfr': 140.0, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 8.3}
#
# {'sex': 'male', 'age': 30.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 20.0, 'systolic_bp': 90.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 3.9}
#
# {'sex': 'male', 'age': 79.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 20.000000000000004, 'systolic_bp': 185.65131020550447, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 16.0, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 23.1}
#
# {'sex': 'female', 'age': 33.50366551905715, 'total_cholesterol': 130.0, 'hdl_cholesterol': 20.0, 'systolic_bp': 90.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 5.6}
#
# {'sex': 'female', 'age': 30.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 20.0, 'systolic_bp': 90.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 5.1}
#
# {'sex': 'female', 'age': 78.0, 'total_cholesterol': 320.0, 'hdl_cholesterol': 100.0, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': True, 'bmi': 39.89999999999999, 'egfr': 16.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 24.3}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 90.00000000000001, 'has_diabetes': True, 'current_smoker': True, 'bmi': 38.9, 'egfr': 140.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 1.4}
#
# {'sex': 'female', 'age': 78.99999999999999, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 90.00000000000001, 'has_diabetes': True, 'current_smoker': True, 'bmi': 38.9, 'egfr': 140.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 14.3}
#
# {'sex': 'male', 'age': 31.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': True, 'current_smoker': False, 'bmi': 19.5, 'egfr': 79.68952687545273, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 2.0}
#
# {'sex': 'male', 'age': 31.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': True, 'current_smoker': False, 'bmi': 18.5, 'egfr': 79.68952687545273, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 2.0}
#
# {'sex': 'male', 'age': 31.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': True, 'current_smoker': False, 'bmi': 18.5, 'egfr': 18.41796875, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 11.7}
#
# {'sex': 'male', 'age': 31.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 18.41796875, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 11.7}
#
# {'sex': 'male', 'age': 31.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': True, 'current_smoker': True, 'bmi': 39.89999999999999, 'egfr': 18.41796875, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 19.9}
#
# {'sex': 'male', 'age': 31.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 39.89999999999999, 'egfr': 18.41796875, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 7.0}
#
# {'sex': 'male', 'age': 31.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 18.41796875, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 3.8}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 144.09639628420422, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.59181390657297, 'egfr': 58.774099747426526, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 0.4}
#
# {'sex': 'female', 'age': 54.09748561750915, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 144.09639628420422, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.59181390657297, 'egfr': 58.774099747426526, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 2.0}
#
# {'sex': 'male', 'age': 30.000000000000004, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 133.5642295623499, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 139.0, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 0.6}
#
# {'sex': 'male', 'age': 30.000000000000004, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 99.99999999999999, 'has_diabetes': False, 'current_smoker': False, 'bmi': 32.61707820892458, 'egfr': 139.0, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 0.4}
#
# {'sex': 'male', 'age': 30.000000000000004, 'total_cholesterol': 320.0, 'hdl_cholesterol': 20.000000000000004, 'systolic_bp': 99.99999999999999, 'has_diabetes': False, 'current_smoker': False, 'bmi': 32.61707820892458, 'egfr': 139.0, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 2.6}
#
# {'sex': 'male', 'age': 30.000000000000004, 'total_cholesterol': 320.0, 'hdl_cholesterol': 20.000000000000004, 'systolic_bp': 99.99999999999999, 'has_diabetes': False, 'current_smoker': True, 'bmi': 32.61707820892458, 'egfr': 139.0, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 4.7}
#
# {'sex': 'male', 'age': 30.000000000000004, 'total_cholesterol': 320.0, 'hdl_cholesterol': 20.000000000000004, 'systolic_bp': 99.99999999999999, 'has_diabetes': True, 'current_smoker': True, 'bmi': 32.61707820892458, 'egfr': 139.0, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 14.4}
#
# {'sex': 'male', 'age': 30.000000000000004, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 99.99999999999999, 'has_diabetes': True, 'current_smoker': True, 'bmi': 32.61707820892458, 'egfr': 139.0, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 2.4}
#
# {'sex': 'male', 'age': 30.000000000000004, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 99.99999999999999, 'has_diabetes': True, 'current_smoker': True, 'bmi': 39.9, 'egfr': 139.0, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 2.4}
#
# {'sex': 'male', 'age': 78.99999999999999, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 139.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 17.6}
#
# {'sex': 'male', 'age': 78.99999999999999, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 139.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 17.6}
#
# {'sex': 'male', 'age': 78.99999999999999, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 139.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 17.6}
#
# {'sex': 'male', 'age': 78.99999999999999, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 139.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 17.6}
#
# {'sex': 'male', 'age': 78.99999999999999, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 139.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 17.5}
#
# {'sex': 'male', 'age': 78.0, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 139.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 16.9}
#
# {'sex': 'male', 'age': 78.0, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.5, 'egfr': 140.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 16.9}
#
# {'sex': 'female', 'age': 49.072652830810156, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.599107517601574, 'egfr': 125.94277322660496, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 4.6}
#
# {'sex': 'female', 'age': 78.99999999999999, 'total_cholesterol': 156.53439880703402, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.599107517601574, 'egfr': 125.94277322660496, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 9.9}
#
# {'sex': 'female', 'age': 78.99999999999999, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.599107517601574, 'egfr': 125.94277322660496, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 12.6}
#
# {'sex': 'female', 'age': 78.99999999999999, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 18.599107517601574, 'egfr': 125.94277322660496, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 12.6}
#
# {'sex': 'female', 'age': 78.99999999999999, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 18.599107517601574, 'egfr': 125.94277322660496, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 16.2}
#
# {'sex': 'female', 'age': 78.99999999999999, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 18.599107517601574, 'egfr': 125.94277322660496, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 16.2}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 200.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 18.599107517601574, 'egfr': 125.94277322660496, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 4.6}
#
# {'sex': 'male', 'age': 78.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': True, 'current_smoker': False, 'bmi': 38.9, 'egfr': 139.99999999999997, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 9.8}
#
# {'sex': 'male', 'age': 78.99999999999999, 'total_cholesterol': 319.0, 'hdl_cholesterol': 21.0, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 39.9, 'egfr': 139.0, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 39.8}
#
# {'sex': 'male', 'age': 78.99999999999999, 'total_cholesterol': 226.484375, 'hdl_cholesterol': 64.37500976171577, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 18.500000000000004, 'egfr': 112.71154945024956, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 21.1}
#
# {'sex': 'male', 'age': 78.0, 'total_cholesterol': 226.484375, 'hdl_cholesterol': 64.37500976171577, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 18.500000000000004, 'egfr': 112.71154945024956, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 20.6}
#
# {'sex': 'female', 'age': 78.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 21.0, 'systolic_bp': 91.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 37.71864180985937, 'egfr': 95.48846649609976, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 13.8}
#
# {'sex': 'female', 'age': 78.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 21.0, 'systolic_bp': 91.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 32.27962546413228, 'egfr': 95.48846649609976, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 13.8}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 130.0, 'hdl_cholesterol': 21.0, 'systolic_bp': 91.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 32.27962546413228, 'egfr': 95.48846649609976, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 0.6}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 131.0, 'hdl_cholesterol': 21.0, 'systolic_bp': 91.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 32.27962546413228, 'egfr': 95.48846649609976, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 0.6}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 252.34246907407163, 'hdl_cholesterol': 21.0, 'systolic_bp': 91.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 32.27962546413228, 'egfr': 95.48846649609976, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 1.7}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 252.34246907407163, 'hdl_cholesterol': 21.0, 'systolic_bp': 91.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 32.27962546413228, 'egfr': 95.48846649609976, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 1.7}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 223.48138491029619, 'hdl_cholesterol': 21.0, 'systolic_bp': 91.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 32.27962546413228, 'egfr': 95.48846649609976, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 1.3}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.0, 'hdl_cholesterol': 20.000000000000004, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': True, 'bmi': 18.5, 'egfr': 140.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 58.1}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': True, 'bmi': 18.5, 'egfr': 140.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 14.0}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': True, 'bmi': 39.89999999999999, 'egfr': 140.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 14.0}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 140.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 7.6}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 140.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 7.6}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 140.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 7.7}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 140.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 7.1}
#
# {'sex': 'female', 'age': 78.99999999999999, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 90.00000000000001, 'has_diabetes': False, 'current_smoker': False, 'bmi': 30.20606071362311, 'egfr': 78.22025308378576, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 11.5}
#
# {'sex': 'female', 'age': 78.99999999999999, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 90.00000000000001, 'has_diabetes': False, 'current_smoker': False, 'bmi': 30.20606071362311, 'egfr': 78.22025308378576, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 11.5}
#
# {'sex': 'female', 'age': 78.99999999999999, 'total_cholesterol': 320.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 90.00000000000001, 'has_diabetes': False, 'current_smoker': False, 'bmi': 30.20606071362311, 'egfr': 78.22025308378576, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 11.5}
#
# {'sex': 'female', 'age': 42.25, 'total_cholesterol': 130.0, 'hdl_cholesterol': 29.31640625, 'systolic_bp': 111.80664062559637, 'has_diabetes': True, 'current_smoker': True, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 24.9}
#
# {'sex': 'female', 'age': 62.739635432929724, 'total_cholesterol': 320.0, 'hdl_cholesterol': 21.0, 'systolic_bp': 157.95544955472488, 'has_diabetes': False, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 16.0, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 30.6}
#
# {'sex': 'male', 'age': 30.0, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 21.0, 'systolic_bp': 91.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.0, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 2.2}
#
# {'sex': 'male', 'age': 30.0, 'total_cholesterol': 319.99999999998937, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 117.82247596894737, 'has_diabetes': False, 'current_smoker': False, 'bmi': 20.339066377538604, 'egfr': 16.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 2.2}
#
# {'sex': 'male', 'age': 30.0, 'total_cholesterol': 319.99999999998937, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 117.82247596894737, 'has_diabetes': False, 'current_smoker': False, 'bmi': 20.339066377538604, 'egfr': 16.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 2.2}
#
# {'sex': 'male', 'age': 30.0, 'total_cholesterol': 319.99999999998937, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 117.82247596894737, 'has_diabetes': False, 'current_smoker': False, 'bmi': 20.339066377538604, 'egfr': 16.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 2.2}
#
# {'sex': 'male', 'age': 30.0, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 90.196533203125, 'systolic_bp': 117.82247596894737, 'has_diabetes': False, 'current_smoker': False, 'bmi': 20.339066377538604, 'egfr': 16.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 2.6}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 244.7552917697683, 'hdl_cholesterol': 58.41349710210305, 'systolic_bp': 199.0, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 13.5}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 176.90624999999994, 'hdl_cholesterol': 58.41349710210305, 'systolic_bp': 199.0, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 7.9}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 58.41349710210305, 'systolic_bp': 199.0, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 23.3}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 118.61554257313716, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 0.9}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 118.61554257313716, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 0.9}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 117.49999999999999, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 0.9}
#
# {'sex': 'female', 'age': 30.000000000000004, 'total_cholesterol': 319.99999999999994, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 117.49999999999999, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 0.9}
#
# {'sex': 'male', 'age': 35.450741241792926, 'total_cholesterol': 131.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 182.40279347534948, 'has_diabetes': True, 'current_smoker': False, 'bmi': 38.9, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 9.5}
#
# {'sex': 'female', 'age': 35.450741241792926, 'total_cholesterol': 131.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 182.40279347534948, 'has_diabetes': True, 'current_smoker': False, 'bmi': 38.9, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 15.1}
#
# {'sex': 'female', 'age': 71.16124436629204, 'total_cholesterol': 131.0, 'hdl_cholesterol': 99.0, 'systolic_bp': 182.40279347534948, 'has_diabetes': True, 'current_smoker': False, 'bmi': 38.9, 'egfr': 15.0, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 14.8}
#
# {'sex': 'male', 'age': 78.0, 'total_cholesterol': 291.875626968234, 'hdl_cholesterol': 20.0, 'systolic_bp': 90.00000000000001, 'has_diabetes': True, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 40.2}
#
# {'sex': 'male', 'age': 78.0, 'total_cholesterol': 180.0048828125, 'hdl_cholesterol': 20.000000000000004, 'systolic_bp': 117.68820013850927, 'has_diabetes': True, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 28.3}
#
# {'sex': 'male', 'age': 78.0, 'total_cholesterol': 320.0, 'hdl_cholesterol': 60.078130960464485, 'systolic_bp': 117.68820013850927, 'has_diabetes': True, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 29.1}
#
# {'sex': 'male', 'age': 42.33383460715413, 'total_cholesterol': 320.0, 'hdl_cholesterol': 60.078130960464485, 'systolic_bp': 117.68820013850927, 'has_diabetes': True, 'current_smoker': False, 'bmi': 18.5, 'egfr': 15.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 20.9}
#
# {'sex': 'male', 'age': 42.25074914097786, 'total_cholesterol': 302.82916837717494, 'hdl_cholesterol': 40.001223091967404, 'systolic_bp': 117.68820013930963, 'has_diabetes': True, 'current_smoker': False, 'bmi': 18.586859130859374, 'egfr': 35.46600648971328, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 11.9}
#
# {'sex': 'female', 'age': 44.59752155666784, 'total_cholesterol': 131.0, 'hdl_cholesterol': 100.0, 'systolic_bp': 143.03815963641748, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.9, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 1.2}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 250.3979274577291, 'hdl_cholesterol': 100.0, 'systolic_bp': 143.03815963641748, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.9, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 1.0}
#
# {'sex': 'female', 'age': 79.0, 'total_cholesterol': 250.3979274577291, 'hdl_cholesterol': 100.0, 'systolic_bp': 143.03815963641748, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.9, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 11.7}
#
# {'sex': 'female', 'age': 79.0, 'total_cholesterol': 174.53125, 'hdl_cholesterol': 100.0, 'systolic_bp': 143.03815963641748, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.9, 'egfr': 139.99999999999997, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 12.1}
#
# {'sex': 'female', 'age': 69.24026766519376, 'total_cholesterol': 185.34303227071746, 'hdl_cholesterol': 29.273089619597066, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': False, 'bmi': 19.5, 'egfr': 44.66405707646969, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 26.5}
#
# {'sex': 'female', 'age': 44.27267674350082, 'total_cholesterol': 185.34303227071746, 'hdl_cholesterol': 29.273089619597066, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': False, 'bmi': 19.5, 'egfr': 44.66405707646969, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 34.1}
#
# {'sex': 'male', 'age': 44.27267674350082, 'total_cholesterol': 185.34303227071746, 'hdl_cholesterol': 29.273089619597066, 'systolic_bp': 199.99999999999997, 'has_diabetes': True, 'current_smoker': False, 'bmi': 19.5, 'egfr': 44.66405707646969, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 28.2}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 1.9}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.0, 'on_htn_meds': True, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 1.9}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.0, 'has_diabetes': False, 'current_smoker': False, 'bmi': 39.89999999999999, 'egfr': 139.0, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 1.8}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.99999999999999, 'systolic_bp': 199.99989674935935, 'has_diabetes': True, 'current_smoker': True, 'bmi': 27.060000000191756, 'egfr': 105.29849535848257, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 16.9}
#
# {'sex': 'female', 'age': 31.0, 'total_cholesterol': 319.0, 'hdl_cholesterol': 99.99992490862498, 'systolic_bp': 90.0, 'has_diabetes': False, 'current_smoker': True, 'bmi': 25.427230563975172, 'egfr': 98.52955262672886, 'on_htn_meds': False, 'on_cholesterol_meds': False, '10_yr_ascvd_risk': 0.3}
#
# {'sex': 'male', 'age': 79.0, 'total_cholesterol': 138.10964570027662, 'hdl_cholesterol': 99.0, 'systolic_bp': 90.00000000000001, 'has_diabetes': True, 'current_smoker': False, 'bmi': 39.9, 'egfr': 16.0, 'on_htn_meds': False, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 12.3}
#
# {'sex': 'male', 'age': 79.0, 'total_cholesterol': 174.56604005012196, 'hdl_cholesterol': 20.0, 'systolic_bp': 150.17001867294312, 'has_diabetes': False, 'current_smoker': False, 'bmi': 35.62000000000009, 'egfr': 66.89505329022461, 'on_htn_meds': True, 'on_cholesterol_meds': True, '10_yr_ascvd_risk': 21.0}

# %%
test_patient = {
    "sex": "female",
    "age": 33.94837059452007,
    "total_cholesterol": 130.0,
    "hdl_cholesterol": 20.0,
    "systolic_bp": 199.99999999999997,
    "has_diabetes": False,
    "current_smoker": True,
    "bmi": 18.500000000000004,
    "egfr": 139.0,
    "on_htn_meds": False,
    "on_cholesterol_meds": True,
    "10_yr_cvd_expected": 9.7,
    "30_yr_cvd_expected": 45.1,
    "10_yr_ascvd_expected": 7.6,
    "30_yr_ascvd_expected": 34.6,
    "10_yr_hf_expected": 2.7,
    "30_yr_hf_expected": 15.8,
}
