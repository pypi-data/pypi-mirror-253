# %%
import pandas as pd
import time
import pyprevent
import jupyter_black

jupyter_black.load(lab=True)
# Out:
#                 <script type="application/javascript" id="jupyter_black">
#                 (function() {
#                     if (window.IPython === undefined) {
#                         return
#                     }
#                     var msg = "WARNING: it looks like you might have loaded " +
#                         "jupyter_black in a non-lab notebook with " +
#                         "`is_lab=True`. Please double check, and if " +
#                         "loading with `%load_ext` please review the README!"
#                     console.log(msg)
#                     alert(msg)
#                 })()
#                 </script>

# %% [markdown]
# ## Data Setup

# %%
test_patient = ("female", 40, 200, 50, 120, True, True, 25, 70, True, True)
test_list = [test_patient for _ in range(1_000_000)]
df = pd.DataFrame(
    test_list,
    columns=[
        "sex",
        "age",
        "total_cholesterol",
        "hdl_cholesterol",
        "systolic_bp",
        "has_diabetes",
        "current_smoker",
        "bmi",
        "egfr",
        "on_htn_meds",
        "on_cholesterol_meds",
    ],
)

# %%
df.iloc[0].to_dict()
# Out:
# {'sex': 'female',
#  'age': 40,
#  'total_cholesterol': 200,
#  'hdl_cholesterol': 50,
#  'systolic_bp': 120,
#  'has_diabetes': True,
#  'current_smoker': True,
#  'bmi': 25,
#  'egfr': 70,
#  'on_htn_meds': True,
#  'on_cholesterol_meds': True}

# %% [markdown]
# ## Individual patient calculations
#
# Taking the first row in the form of a dict, we have a test patient.
#
# The keys of this dictionary are the input arguments for all of the functions.
#
# Here, we can pass the dictionary as kwargs to return the risk. Of note this float represents the risk as a percentage.

# %%
pyprevent.calculate_10_yr_ascvd_risk(**df.iloc[0].to_dict())
# Out:
# 4.723678963112583

# %% [markdown]
# (You can also pass in the arguments like a normal python function)

# %%
pyprevent.calculate_30_yr_ascvd_risk(
    sex="MALE",
    age=40,
    total_cholesterol=200,
    hdl_cholesterol=50,
    systolic_bp=120,
    has_diabetes=False,
    current_smoker=False,
    bmi=25,
    egfr=70,
    on_htn_meds=False,
    on_cholesterol_meds=False,
)
# Out:
# 7.008061525002453

# %% [markdown]
# All of the inputs have constains, and will return an error if the values are outside of the acceptable range.
#
# These ranges are set by the AHA PREVENT formulas to constain any extrapolation at extreme values.

# %%
pyprevent.calculate_30_yr_ascvd_risk(
    
    sex="unknown",

    
    age=40,
    total_cholesterol=200,
    hdl_cholesterol=50,
    systolic_bp=120,
    has_diabetes=False,
    current_smoker=False,
    bmi=25,
    egfr=70,
    on_htn_meds=False,
    on_cholesterol_meds=False,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 pyprevent.calculate_30_yr_ascvd_risk(
#       2
#       3     sex="unknown",
#       4
#       5
#       6     age=40,
#       7     total_cholesterol=200,
#       8     hdl_cholesterol=50,
#       9     systolic_bp=120,
#      10     has_diabetes=False,
#      11     current_smoker=False,
#      12     bmi=25,
#      13     egfr=70,
#      14     on_htn_meds=False,
#      15     on_cholesterol_meds=False,
#      16 )
#
# File ~/miniconda3/envs/pyprevent/lib/python3.10/site-packages/pyprevent/ascvd_calc.py:46, in calculate_30_yr_ascvd_risk(sex, age, total_cholesterol, hdl_cholesterol, systolic_bp, has_diabetes, current_smoker, bmi, egfr, on_htn_meds, on_cholesterol_meds)
#      33 def calculate_30_yr_ascvd_risk(
#      34     sex: str,
#      35     age: float,
#    (...)
#      44     on_cholesterol_meds: bool,
#      45 ) -> float:
# ---> 46     return _pyprevent.calculate_30_yr_ascvd_rust(
#      47         sex,
#      48         age,
#      49         total_cholesterol,
#      50         hdl_cholesterol,
#      51         systolic_bp,
#      52         has_diabetes,
#      53         current_smoker,
#      54         bmi,
#      55         egfr,
#      56         on_htn_meds,
#      57         on_cholesterol_meds,
#      58     )
#
# ValueError: Sex must be either 'male' or 'female'.

# %%
pyprevent.calculate_30_yr_ascvd_risk(
    sex="male",
    
    age=10,
    
    total_cholesterol=200,
    hdl_cholesterol=50,
    systolic_bp=120,
    has_diabetes=False,
    current_smoker=False,
    bmi=25,
    egfr=70,
    on_htn_meds=False,
    on_cholesterol_meds=False,
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 pyprevent.calculate_30_yr_ascvd_risk(
#       2     sex="male",
#       3
#       4     age=10,
#       5
#       6     total_cholesterol=200,
#       7     hdl_cholesterol=50,
#       8     systolic_bp=120,
#       9     has_diabetes=False,
#      10     current_smoker=False,
#      11     bmi=25,
#      12     egfr=70,
#      13     on_htn_meds=False,
#      14     on_cholesterol_meds=False,
#      15 )
#
# File ~/miniconda3/envs/pyprevent/lib/python3.10/site-packages/pyprevent/ascvd_calc.py:46, in calculate_30_yr_ascvd_risk(sex, age, total_cholesterol, hdl_cholesterol, systolic_bp, has_diabetes, current_smoker, bmi, egfr, on_htn_meds, on_cholesterol_meds)
#      33 def calculate_30_yr_ascvd_risk(
#      34     sex: str,
#      35     age: float,
#    (...)
#      44     on_cholesterol_meds: bool,
#      45 ) -> float:
# ---> 46     return _pyprevent.calculate_30_yr_ascvd_rust(
#      47         sex,
#      48         age,
#      49         total_cholesterol,
#      50         hdl_cholesterol,
#      51         systolic_bp,
#      52         has_diabetes,
#      53         current_smoker,
#      54         bmi,
#      55         egfr,
#      56         on_htn_meds,
#      57         on_cholesterol_meds,
#      58     )
#
# ValueError: Age must be between 30 and 59

# %% [markdown]
# ## Batch Calculations
#
# There are also functions to batch apply this function.
#
# In our test data set, we have a million patients.

# %%
print(len(df))
# Out:
# 1000000

# %%
pyprevent.batch_calculate_10_yr_ascvd_risk(df)
# Out:
# [4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  4.723678963112583,
#  ...]

# %%
start = time.perf_counter()
pyprevent.batch_calculate_30_yr_ascvd_risk(df)
end = time.perf_counter()
duration = end - start
print(f"Time to run 1 million rows: {duration} seconds")
# Out:
# Time to run 1 million rows: 0.8204120000009425 seconds

# %% [markdown]
# ## Data validation
#
# Again, if a value is invalid, the batch methods will return a ValueError.

# %%
# Setting age to 100.0 near the end of the dataframe
df.loc[999_998, "age"] = 100.0
print(df.iloc[-2])
pyprevent.batch_calculate_30_yr_ascvd_risk(df)
# Out:
# sex                    female
# age                       100
# total_cholesterol         200
# hdl_cholesterol            50
# systolic_bp               120
# has_diabetes             True
# current_smoker           True
# bmi                        25
# egfr                       70
# on_htn_meds              True
# on_cholesterol_meds      True
# Name: 999998, dtype: object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 4
#       2 df.loc[999_998, "age"] = 100.0
#       3 print(df.iloc[-2])
# ----> 4 pyprevent.batch_calculate_30_yr_ascvd_risk(df)
#
# File ~/miniconda3/envs/pyprevent/lib/python3.10/site-packages/pyprevent/ascvd_calc.py:71, in batch_calculate_30_yr_ascvd_risk(df)
#      69 def batch_calculate_30_yr_ascvd_risk(df: pd.DataFrame) -> list:
#      70     new_df = df.copy()
# ---> 71     return [
#      72         _pyprevent.calculate_30_yr_ascvd_rust(*row)
#      73         for row in new_df.itertuples(index=False)
#      74     ]
#
# File ~/miniconda3/envs/pyprevent/lib/python3.10/site-packages/pyprevent/ascvd_calc.py:72, in <listcomp>(.0)
#      69 def batch_calculate_30_yr_ascvd_risk(df: pd.DataFrame) -> list:
#      70     new_df = df.copy()
#      71     return [
# ---> 72         _pyprevent.calculate_30_yr_ascvd_rust(*row)
#      73         for row in new_df.itertuples(index=False)
#      74     ]
#
# ValueError: Age must be between 30 and 59
